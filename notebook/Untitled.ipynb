# %%
# Import required libraries
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns
from sklearn import preprocessing
# %matplotlib inline
from pandas.tools.plotting import table

# %%
# import csv dataset as pandas dataframe
odi_dataframe = pd.read_csv("../data/ODI-2018.csv", sep=',')

# %%
print(odi_dataframe)
# Out:
#              Timestamp                      What programme are you in?  \
# 0                  NaN                                             NaN
# 1    4/5/2018 11:22:56         Duisenberg Quantitative Risk Management
# 2    4/5/2018 11:23:04                                Computer Science
# 3    4/5/2018 11:23:06                              Business Analytics
# 4    4/5/2018 11:23:50                                              BA
# 5    4/5/2018 11:23:59   Master Computer Science: Big Data Engineering
# 6    4/5/2018 11:24:34                       Drug discovery and safety
# 7    4/5/2018 11:25:25                                              CS
# 8    4/5/2018 11:25:25                           Computational Science
# 9    4/5/2018 11:25:36                         M Financial Economtrics
# 10   4/5/2018 11:25:51          MSc Bioinformatics and Systems Biology
# 11   4/5/2018 11:25:54                                    Econometrics
# ...

# %%
odi_dataframe.describe()
# Out:
#                 Timestamp What programme are you in?  \
# count                 217                        217
# unique                102                         91
# top     4/5/2018 11:27:35                         AI
# freq                    8                         37
#
#        Have you taken a course on machine learning?  \
# count                                           217
# unique                                            3
# top                                             yes
# freq                                            120
#
#        Have you taken a course on information retrieval?  \
# count                                                217
# unique                                                 3
# top                                                    0
# freq                                                 133
#
#        Have you taken a course on statistics?  \
# count                                     217
# ...

# %%
gender=odi_dataframe[odi_dataframe.columns[6]]
print(gender)
# Out:
# 0         NaN
# 1        male
# 2        male
# 3        male
# 4        male
# 5        male
# 6        male
# 7        male
# 8        male
# 9        male
# 10       male
# 11     female
# 12     female
# 13     female
# 14       male
# 15       male
# 16     female
# 17     female
# 18       male
# 19     female
# 20       male
# 21       male
# 22       male
# 23       male
# 24     female
# 25     female
# 26       male
# 27       male
# 28     female
# 29       male
#         ...
# 188    female
# 189      male
# 190      male
# 191      male
# 192      male
# 193    female
# 194      male
# 195      male
# 196      male
# 197    female
# 198    female
# 199    female
# 200      male
# 201      male
# 202      male
# 203      male
# 204      male
# 205      male
# 206      male
# 207      male
# 208      male
# 209      male
# 210    female
# 211      male
# 212      male
# 213      male
# 214    female
# 215      male
# 216      male
# 217      male
# ...

# %%
gender.drop(gender.index[0])
# Out:
# 1        male
# 2        male
# 3        male
# 4        male
# 5        male
# 6        male
# 7        male
# 8        male
# 9        male
# 10       male
# 11     female
# 12     female
# 13     female
# 14       male
# 15       male
# 16     female
# 17     female
# 18       male
# 19     female
# 20       male
# 21       male
# 22       male
# 23       male
# 24     female
# 25     female
# 26       male
# 27       male
# 28     female
# 29       male
# 30     female
#         ...
# 188    female
# 189      male
# 190      male
# 191      male
# 192      male
# 193    female
# 194      male
# 195      male
# 196      male
# 197    female
# 198    female
# 199    female
# 200      male
# 201      male
# 202      male
# 203      male
# 204      male
# 205      male
# 206      male
# 207      male
# 208      male
# 209      male
# 210    female
# 211      male
# 212      male
# 213      male
# 214    female
# 215      male
# 216      male
# 217      male
# ...

# %%
plt.figure(figsize=(16,8))
# plot chart
ax1 = plt.subplot(121, aspect='equal')
gender.plot(kind='pie', y = gender, ax=ax1, autopct='%1.1f%%', 
 startangle=90, shadow=False, legend = False, fontsize=14)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-2ee01d870753> in <module>()
#       3 ax1 = plt.subplot(121, aspect='equal')
#       4 gender.plot(kind='pie', y = gender, ax=ax1, autopct='%1.1f%%',
# ----> 5  startangle=90, shadow=False, legend = False, fontsize=14)
#
# C:\Users\mary the magnificent\Anaconda2\lib\site-packages\pandas\plotting\_core.pyc in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2501                            colormap=colormap, table=table, yerr=yerr,
#    2502                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2503                            **kwds)
#    2504     __call__.__doc__ = plot_series.__doc__
#    2505
#
# ...
